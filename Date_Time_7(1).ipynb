# %% [markdown]
# # 17/11/22

# %% [markdown]
# Date time data

# %%
import pandas as pd 
import numpy as np
import seaborn as sns

# %%
df=pd.read_excel("C:\\Users\\rupan\\OneDrive\\Desktop\\data_sets\\catalog.xlsx")
df
# Out:
#         id                 date      time continent_code   country_name  \
# 0       34  2007-02-03 00:00:00     Night            NaN  United States
# 1       42              3/22/07       NaN            NaN  United States
# 2       56  2007-06-04 00:00:00       NaN            NaN  United States
# 3       59              4/14/07       NaN            NaN         Canada
# 4       61              4/15/07       NaN            NaN  United States
# ...    ...                  ...       ...            ...            ...
# 1688  7535  2015-07-12 00:00:00       NaN            NaN  United States
# 1689  7537              2/22/16  00:00:00            NaN  United States
# 1690  7539              2/23/16       NaN            NaN  United States
# 1691  7540              2/26/16  21:06:00            NaN  United States
# 1692  7541  2016-02-03 00:00:00  08:00:00            NaN  United States
#
#      country_code  state/province  population         city/town  distance  \
# ...

# %%
# check date type first always
df.info() 
# first convert it into data-time type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1693 entries, 0 to 1692
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1693 non-null   int64
#  1   date                  1690 non-null   object
#  2   time                  629 non-null    object
#  3   continent_code        164 non-null    object
#  4   country_name          1693 non-null   object
#  5   country_code          1693 non-null   object
#  6   state/province        1692 non-null   object
#  7   population            1693 non-null   int64
#  8   city/town             1689 non-null   object
#  9   distance              1692 non-null   float64
#  10  location_description  551 non-null    object
#  11  latitude              1692 non-null   float64
#  12  longitude             1692 non-null   float64
#  13  geolocation           1692 non-null   object
#  14  hazard_type           1693 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# id                         0
# date                       3
# time                    1064
# continent_code          1529
# country_name               0
# country_code               0
# state/province             1
# population                 0
# city/town                  4
# distance                   1
# location_description    1142
# latitude                   1
# longitude                  1
# geolocation                1
# hazard_type                0
# landslide_type             1
# landslide_size             1
# trigger                    2
# storm_name              1561
# injuries                1178
# fatalities               247
# source_name              821
# source_link              100
# dtype: int64

# %%
#called filling or imputing

# %%
df["date"].fillna(df["date"].mode()[0],inplace=True)  
#mode can have more than one repetitive value, we want first entry so we gave index[0]

# %%
df.isnull().sum()
# Out:
# id                         0
# date                       0
# time                    1064
# continent_code          1529
# country_name               0
# country_code               0
# state/province             1
# population                 0
# city/town                  4
# distance                   1
# location_description    1142
# latitude                   1
# longitude                  1
# geolocation                1
# hazard_type                0
# landslide_type             1
# landslide_size             1
# trigger                    2
# storm_name              1561
# injuries                1178
# fatalities               247
# source_name              821
# source_link              100
# dtype: int64

# %%
# converting date to datetime datatype
df["date"]=pd.to_datetime(df["date"])

# %%
df.dtypes
# Out:
# id                               int64
# date                    datetime64[ns]
# time                            object
# continent_code                  object
# country_name                    object
# country_code                    object
# state/province                  object
# population                       int64
# city/town                       object
# distance                       float64
# location_description            object
# latitude                       float64
# longitude                      float64
# geolocation                     object
# hazard_type                     object
# landslide_type                  object
# landslide_size                  object
# trigger                         object
# storm_name                      object
# injuries                       float64
# fatalities                     float64
# source_name                     object
# source_link                     object
# dtype: object

# %%
#df.drop(columns=["continent_code","state/province","city/town","distance","location_description","latitude","longitude","geolocation","landslide_size","trigger","storm_name","injuries","fatalities","source_name","source_link"])

# %%
df.drop(columns=["continent_code","location_description","source_link","source_name","fatalities","storm_name","injuries","city/town","distance","latitude","longitude","landslide_size","trigger"],inplace=True)

# %%
df
# Out:
#         id       date      time   country_name country_code  state/province  \
# 0       34 2007-02-03     Night  United States           US        Virginia
# 1       42 2007-03-22       NaN  United States           US            Ohio
# 2       56 2007-06-04       NaN  United States           US    Pennsylvania
# 3       59 2007-04-14       NaN         Canada           CA          Quebec
# 4       61 2007-04-15       NaN  United States           US        Kentucky
# ...    ...        ...       ...            ...          ...             ...
# 1688  7535 2015-07-12       NaN  United States           US  North Carolina
# 1689  7537 2016-02-22  00:00:00  United States           US   West Virginia
# 1690  7539 2016-02-23       NaN  United States           US   West Virginia
# 1691  7540 2016-02-26  21:06:00  United States           US   West Virginia
# 1692  7541 2016-02-03  08:00:00  United States           US         Vermont
#
# ...

# %%
df.isnull().sum()
# Out:
# id                   0
# date                 0
# time              1064
# country_name         0
# country_code         0
# state/province       1
# population           0
# geolocation          1
# hazard_type          0
# landslide_type       1
# dtype: int64

# %%
df["landslide_type"].fillna(df["landslide_type"].mode()[0],inplace=True)

# %%
from datetime import datetime as dt  # dt is alias

# %%
#creating a new column name year and extracting year from date column
df["year"]=df.date.dt.year
df
# Out:
#         id       date      time   country_name country_code  state/province  \
# 0       34 2007-02-03     Night  United States           US        Virginia
# 1       42 2007-03-22       NaN  United States           US            Ohio
# 2       56 2007-06-04       NaN  United States           US    Pennsylvania
# 3       59 2007-04-14       NaN         Canada           CA          Quebec
# 4       61 2007-04-15       NaN  United States           US        Kentucky
# ...    ...        ...       ...            ...          ...             ...
# 1688  7535 2015-07-12       NaN  United States           US  North Carolina
# 1689  7537 2016-02-22  00:00:00  United States           US   West Virginia
# 1690  7539 2016-02-23       NaN  United States           US   West Virginia
# 1691  7540 2016-02-26  21:06:00  United States           US   West Virginia
# 1692  7541 2016-02-03  08:00:00  United States           US         Vermont
#
# ...

# %%
#df.head()

# %%
df["year"].unique()
# Out:
# array([2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016],
#       dtype=int64)

# %%
#extracting month
df["month"]=df.date.dt.month
df
# Out:
#         id       date      time   country_name country_code  state/province  \
# 0       34 2007-02-03     Night  United States           US        Virginia
# 1       42 2007-03-22       NaN  United States           US            Ohio
# 2       56 2007-06-04       NaN  United States           US    Pennsylvania
# 3       59 2007-04-14       NaN         Canada           CA          Quebec
# 4       61 2007-04-15       NaN  United States           US        Kentucky
# ...    ...        ...       ...            ...          ...             ...
# 1688  7535 2015-07-12       NaN  United States           US  North Carolina
# 1689  7537 2016-02-22  00:00:00  United States           US   West Virginia
# 1690  7539 2016-02-23       NaN  United States           US   West Virginia
# 1691  7540 2016-02-26  21:06:00  United States           US   West Virginia
# 1692  7541 2016-02-03  08:00:00  United States           US         Vermont
#
# ...

# %%
# extracting month name
df["m_name"]=df.date.dt.month_name()
df["m_name"]
# Out:
# 0       February
# 1          March
# 2           June
# 3          April
# 4          April
#           ...
# 1688        July
# 1689    February
# 1690    February
# 1691    February
# 1692    February
# Name: m_name, Length: 1693, dtype: object

# %%
df["m_name"].unique()
# Out:
# array(['February', 'March', 'June', 'April', 'May', 'January', 'August',
#        'July', 'September', 'November', 'December', 'October'],
#       dtype=object)

# %%
#extracting day
df["day"]=df.date.dt.day
df["day"].unique()
# Out:
# array([ 3, 22,  4, 14, 15, 20, 24, 21, 27,  7, 13,  8, 17, 18, 19, 23,  9,
#        28, 10, 29, 31, 11, 30, 12, 16,  1,  2, 25,  5,  6, 26],
#       dtype=int64)

# %%
#extracting dayname
df["day_name"]=df.date.dt.day_name()
df["day_name"].unique()
# Out:
# array(['Saturday', 'Thursday', 'Monday', 'Sunday', 'Friday', 'Tuesday',
#        'Wednesday'], dtype=object)

# %%
#extracting day of week
df["d_week"]=df.date.dt.dayofweek
df["d_week"].unique()
# Out:
# array([5, 3, 0, 6, 4, 1, 2], dtype=int64)

# %%
#extracting  week of year
df["week_no"]=df.date.dt.week
df["week_no"].unique()
# Out:
# C:\Users\rupan\AppData\Local\Temp\ipykernel_26744\1770653043.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["week_no"]=df.date.dt.week
# array([ 5, 12, 23, 15, 16, 17, 21, 26,  1, 14, 32, 28, 30, 36, 45, 33, 34,
#         2,  6, 10, 19, 38, 39, 37, 50, 41, 42, 43, 44, 46, 48, 51, 22, 27,
#        18,  9, 40, 11, 13, 49, 25, 29, 31, 35, 24, 47, 52,  4, 20, 53,  3,
#         7,  8], dtype=int64)

# %%
# extracting weekend   #1 is for weekend and o is for weekdays
import numpy as np
df["date is weekend"]=np.where(df["day_name"].isin(["Sunday","Saturday"]),1,0)
df["date is weekend"]
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       1
#        ..
# 1688    1
# 1689    0
# 1690    0
# 1691    0
# 1692    0
# Name: date is weekend, Length: 1693, dtype: int32

# %%
# extracting quarter
df["quarter"]=df.date.dt.quarter
df["quarter"].unique()
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
df["time"].fillna(df["time"].mode()[0],inplace=True)

# %%
df["time"]
# Out:
# 0          Night
# 1          Night
# 2          Night
# 3          Night
# 4          Night
#           ...
# 1688       Night
# 1689    00:00:00
# 1690       Night
# 1691    21:06:00
# 1692    08:00:00
# Name: time, Length: 1693, dtype: object

# %%
df["time"].dtype
# Out:
# dtype('O')

# %%
#df["time"]=pd.to_datetime(df["time"])

# %%
## current date and time
import datetime
today=datetime.datetime.today()
today
# Out:
# datetime.datetime(2022, 11, 17, 11, 24, 22, 238688)

# %%
today-df["date"]
# Out:
# 0      5766 days 11:24:22.238688
# 1      5719 days 11:24:22.238688
# 2      5645 days 11:24:22.238688
# 3      5696 days 11:24:22.238688
# 4      5695 days 11:24:22.238688
#                   ...
# 1688   2685 days 11:24:22.238688
# 1689   2460 days 11:24:22.238688
# 1690   2459 days 11:24:22.238688
# 1691   2456 days 11:24:22.238688
# 1692   2479 days 11:24:22.238688
# Name: date, Length: 1693, dtype: timedelta64[ns]

# %%
## month difference
np.round((today-df["date"])/np.timedelta64(1,"M"),0)
# Out:
# 0       189.0
# 1       188.0
# 2       185.0
# 3       187.0
# 4       187.0
#         ...
# 1688     88.0
# 1689     81.0
# 1690     81.0
# 1691     81.0
# 1692     81.0
# Name: date, Length: 1693, dtype: float64

# %%
df["time"]=df["date"].dt.time
df
# Out:
#         id       date      time   country_name country_code  state/province  \
# 0       34 2007-02-03  00:00:00  United States           US        Virginia
# 1       42 2007-03-22  00:00:00  United States           US            Ohio
# 2       56 2007-06-04  00:00:00  United States           US    Pennsylvania
# 3       59 2007-04-14  00:00:00         Canada           CA          Quebec
# 4       61 2007-04-15  00:00:00  United States           US        Kentucky
# ...    ...        ...       ...            ...          ...             ...
# 1688  7535 2015-07-12  00:00:00  United States           US  North Carolina
# 1689  7537 2016-02-22  00:00:00  United States           US   West Virginia
# 1690  7539 2016-02-23  00:00:00  United States           US   West Virginia
# 1691  7540 2016-02-26  00:00:00  United States           US   West Virginia
# 1692  7541 2016-02-03  00:00:00  United States           US         Vermont
#
# ...

# %%
# how many landslide happen year-wise
df.groupby(["year"])["landslide_type"].value_counts().sort_values(ascending=False)
# Out:
# year  landslide_type
# 2010  Landslide             179
# 2015  Landslide             154
# 2011  Landslide             154
# 2010  Mudslide              132
# 2013  Mudslide              127
#       Landslide             123
# 2011  Mudslide              116
# 2014  Landslide             104
# 2015  Mudslide               73
# 2014  Mudslide               66
# 2012  Landslide              48
# 2008  Mudslide               48
#       Landslide              42
# 2007  Landslide              40
# 2009  Mudslide               34
# 2007  Mudslide               21
# 2010  Complex                20
# 2015  Rockfall               20
# 2009  Landslide              18
# 2012  Mudslide               17
# 2013  Debris flow            15
# 2016  Rockfall               13
# 2008  Complex                10
# 2014  Rockfall               10
# 2007  Complex                 9
# 2010  Rockfall                9
# 2015  Other                   9
# 2009  Rockfall                8
# ...

# %%
date=pd.date_range("1/1/2000",periods=12,freq="M")  ## date range is a pandas function to generate dates 
date   #now its giving output in month difference
# Out:
# DatetimeIndex(['2000-01-31', '2000-02-29', '2000-03-31', '2000-04-30',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-30', '2000-10-31', '2000-11-30', '2000-12-31'],
#               dtype='datetime64[ns]', freq='M')
